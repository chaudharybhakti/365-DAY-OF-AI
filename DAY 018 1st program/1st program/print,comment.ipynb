# %%
print(5)
# Out:
# 5

# %%
print("hloo world")
# Out:
# hloo world

# %%
print("hlooo",5,"dear")
# Out:
# hlooo 5 dear

# %%
print(12+45)
# Out:
# 57

# %%
print("hloo bhakti \n how are you")#we use \n to print the sentence on the next line
# Out:
# hloo bhakti
#  how are you

# %%
#This is a 'Single-Line Comment'
print("This is a print statement.")
# Out:
# This is a print statement.

# %%
#It will execute a block of code if a specified condition is true.
#If the condition is false then it will execute another block of code.
p = 7
if (p > 5):
    print("p is greater than 5.")
else:
    print("p is not greater than 5.")
# Out:
# p is greater than 5.

# %%
"""This is an if-else statement.
It will execute a block of code if a specified condition is true.
If the condition is false then it will execute another block of code.
THIS IS THE EXAMPLE OF MULTI LINE STRING"""
p = 7
if (p > 5):
    print("p is greater than 5.")
else:
    print("p is not greater than 5.")
# Out:
# p is greater than 5.

# %%
print("heyy i am a good girl\nand i love flowers")#by using \n we print  the text on the line
# Out:
# heyy i am a good girl
# and i love flowers

# %%
print("This will \" execute")#Escape Sequence Characters
# Out:
# This will " execute

# %%
print("hey",3,4,sep=">>>>")#this is the sep parameter which will sep all the characters in the print statement
# Out:
# hey>>>>3>>>>4

# %%
print("hey",3,4, "end=333")
# Out:
# hey 3 4 end=333
