# %%
print("h")
# Out:
# h

# %%
import numpy

# %%
import pandas

# %%
import matplotlib

# %%
import pandas as pd
import numpy as np
# Creating empty series
ser = pd.Series()
print(ser)
# simple array
data = np.array(['M', 'I', 'C', 'R', 'O'])
ser = pd.Series(data)
print(ser)
# Out:
# Series([], dtype: object)
# 0    M
# 1    I
# 2    C
# 3    R
# 4    O
# dtype: object
