# %%
a=input()
print("my name is",a)
# Out:
# my name is bhakti

# %% [markdown]
# In python, we can take user input directly by using input() function
# Syntax:
# variable=input()
# But input function returns the value as string. Hence we have to typecast them whenever required to another datatype.
#
# Example:
# variable=int(input())
# variable=float(input())

# %% [markdown]
# We can also display a text using input function. This will make input() function take user input and display a message as well
#
# Example:
# a=input("Enter the name: ")
# print(a)

# %%
a=input("enter your branch")
print("my branch is ",a)
# Out:
# my branch is  Artificial Intelligence

# %%
x=input("enter first no:")
y=input("enter second no:")
print(x+y)
# Out:
# 3445

# %%
x=input("enter first no:")
y=input("enter second no:")
print(int(x)+int(y))#this performs actual arithmatic operation between two int values
print(x+y)#this will concatinate the string
# Out:
# 9
# 45
