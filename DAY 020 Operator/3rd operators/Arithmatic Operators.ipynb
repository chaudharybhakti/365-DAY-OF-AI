# %%
print(3+6)
print(3-6)
print(3*6)
print(8/9)
print(8//9)
print(3**6)
print(3%6)
# Out:
# 9
# -3
# 18
# 0.8888888888888888
# 0
# 729
# 3

# %% [markdown]
# floor division operator(//) is used to remove the point from the ans of division and
# modulus operator returns the remainder

# %%
n = 15
m = 7
a= n+m
print("Addition of",n,"and",m,"is", a)
b= n-m
print("Subtraction of",n,"and",m,"is", b)
c= n*m
print("Multiplication of",n,"and",m,"is", c)
d= n/m
print("Division of",n,"and",m,"is", d)
e= n%m
print("Modulus of",n,"and",m,"is", e)
f= n//m
print("Floor Division of",n,"and",m,"is",f )
# Out:
# Addition of 15 and 7 is 22
# Subtraction of 15 and 7 is 8
# Multiplication of 15 and 7 is 105
# Division of 15 and 7 is 2.142857142857143
# Modulus of 15 and 7 is 1
# Floor Division of 15 and 7 is 2
