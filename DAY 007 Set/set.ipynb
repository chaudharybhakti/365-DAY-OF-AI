# %%
my_set = {10, 20, 30, 40}

print(my_set)
# Out:
# {40, 10, 20, 30}

# %%
my_set = {1, 2, 3, 2, 4, 1}

print(my_set)
# Out:
# {1, 2, 3, 4}

# %%
my_set = {10, 20, 30}

my_set.add(40)

print(my_set)
# Out:
# {40, 10, 20, 30}

# %%
my_set = {10, "Hello", 3.5, True}

print(my_set)
# Out:
# {3.5, True, 'Hello', 10}

# %%
a = {10, 20}

a.add(30)

print(a)
# Out:
# {10, 20, 30}
