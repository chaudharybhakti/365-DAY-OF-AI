# %%
a = {10, 20}

a.update([30, 40, 50])

print(a)
# Out:
# {40, 10, 50, 20, 30}

# %%
a = {10, 20, 30}

a.remove(20)

print(a)
# Out:
# {10, 30}

# %%
a = {10, 20, 30}

a.discard(20)

print(a)
# Out:
# {10, 30}

# %%
a = {10, 20, 30}

a.pop()

print(a)
# Out:
# {20, 30}

# %%
a = {10, 20, 30}

a.clear()

print(a)
# Out:
# set()
