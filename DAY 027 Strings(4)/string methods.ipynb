# %% [markdown]
# Stirings are immutable(means we cannot change the string)
# but we able to change the string by another name means it is not completely immutable
# **string methods operate on existing string and make new string

# %%
a="Bhakti"
b="!!!!naman!!!!!!!!!"
c="my name is Bhakti,Bhakti is a data analyst"
d="this is moon"
heading="cloud computing"
m="think and grow rich\n"
print(a)
print(len(a))#this is the operation
print(a.lower())#The lower() method converts a string to lower case.This is the method,it will operate on existing string and make new string
print(a.upper())#The upper() method converts a string to upper case.
print(b.rstrip("!"))#he rstrip() removes any trailing characters.but it will only removes the character which is only after the string not before means not leading characters.
# Out:
# Bhakti
# 6
# bhakti
# BHAKTI
# !!!!naman

# %%
print(a.replace("Bhakti","Disha"))#The replace() method replaces all occurences of a string with another string.
print(c.replace("Bhakti","Disha"))
print(d.replace("m","n"))
# Out:
# Disha
# my name is Disha,Disha is a data analyst
# this is noon

# %%
print(b.rstrip("!"))#he rstrip() removes any trailing characters.but it will only removes the character which is only after the string not before means not leading characters
# Out:
# !!!!naman

# %%
print(d.split(" "))#The split() method splits the given string at the specified instance and returns the separated strings as list items.
print(c.split(" "))#split the string at the white spaces
# Out:
# ['this', 'is', 'moon']
# ['my', 'name', 'is', 'Bhakti,Bhakti', 'is', 'a', 'data', 'analyst']

# %%
print(heading.capitalize())#The capitalize() method turns only the first character of the string to uppercase and the rest other characters of the string are turned to lowercase. The string has no effect if the first character is already uppercase.
# Out:
# Cloud computing

# %%
str1 = "hello"
capStr1 = str1.capitalize()
print(capStr1)
str2 = "hello WorlD"#it will convert only first letter in uppercase and other letter in lowercase.
capStr2 = str2.capitalize()
print(capStr2)
"""The capitalize() method turns only the first character of the string to uppercase and the rest other characters of the string are turned to lowercase. 
The string has no effect if the first character is already uppercase."""
# Out:
# Hello
# Hello world
# 'The capitalize() method turns only the first character of the string to uppercase and the rest other characters of the string are turned to lowercase. \nThe string has no effect if the first character is already uppercase.'

# %%
print(a.center(60))#The center() method aligns the string to the center as per the parameters given by the user.
print(len(a.center(60)))
print(a.center(60,"*"))
# Out:
#                            Bhakti
# 60
# ***************************Bhakti***************************

# %%
print(c.count("Bhakti"))#The count() method returns the number of times the given value has occurred within the given string.
# Out:
# 2

# %%
print(b.endswith("!"))##The endswith() method checks if the string ends with a given value. If yes then return True, else return False.
print(c.endswith("!"))
print(c.endswith("is",4,9))#We can even also check for a value in-between the string by providing start and end index positions.
print(c.endswith("is",4,10))
# Out:
# True
# False
# False
# True

# %%
print(c.find("is"))#The find() method searches for the first occurrence of the given value and returns the index where it is present. If given value is absent from the string then return -1.
print(c.find("on"))
# Out:
# 8
# -1

# %%
f=("calude is a perfect AI platform for the research")#The find() method searches for the first occurrence of the given value and returns the index where it is present. If given value is absent from the string then return -1.
print(f.find("is"))
"""As we can see, this method is somewhat similar to the index() method. 
The major difference being that index() raises an exception if value is absent whereas find() does not."""
# Out:
# 7
# 'As we can see, this method is somewhat similar to the index() method. \nThe major difference being that index() raises an exception if value is absent whereas find() does not.'

# %%
print(c.index("is"))#The index() method searches for the first occurrence of the given value and returns the index where it is present. If given value is absent from the string then raise an exception.
# Out:
# 8

# %%
name="my name is rashi,she is a good girl"
print(name.index("is"))
#print(name.index("on"))"""The index() method searches for the first occurrence of the given value 
##If given value is absent from the string then raise an exception."""
# Out:
# 8

# %%
print(c.isalnum())#The isalnum() method returns True only if the entire string only consists of A-Z, a-z, 0-9. If any other characters or punctuations are present, then it returns False.
print(a.isalnum())
# Out:
# False
# True

# %%
print(a.isalpha())#The isalnum() method returns True only if the entire string only consists of A-Z, a-z. If any other characters or punctuations or numbers(0-9) are present, then it returns False.
print(c.isalpha())
# Out:
# True
# False

# %%
print(c.islower())#The islower() method returns True if all the characters in the string are lower case, else it returns False.
print(d.islower())
# Out:
# False
# True

# %%
print(a.isprintable())#The isprintable() method returns True if all the values within the given string are printable, if not, then return False.
print(m)
print(m.isprintable())#printable means the character is visible when we print the statement,here we give \n but it is not printable thats why it shows false
# Out:
# True
# think and grow rich
#
# False

# %%
print(c.isspace())#The isspace() method returns True only and only if the string contains white spaces, else returns False.
m="     "
print(m.isspace())
# Out:
# False
# True

# %%
str1 = "World Health Organization"#The istitile() returns True only if the first letter of each word of the string is capitalized, else it returns False.
print(str1.istitle())
str2="bhaktu"
print(str2.istitle())
str3="My name is Bhakti"
print(str3.istitle())
str4="I LOVE MY COUNTRY"
print(str4.istitle())
str5="I Love My Country"
print(str5.istitle())
# Out:
# True
# False
# False
# False
# True

# %%
m = "WORLD HEALTH ORGANIZATION" #The isupper() method returns True if all the characters in the string are upper case, else it returns False.
print(m.isupper())
print(str4.isupper())
print(str5.isupper())
# Out:
# True
# True
# False

# %%
firstword="Chatgpt is a chatbot"#The startswith() method checks if the string starts with a given value. If yes then return True, else return False.
print(firstword.startswith("Chatgpt"))
# Out:
# True

# %%
z = "Python is a Interpreted Language" #The swapcase() method changes the character casing of the string. Upper case are converted to lower case and lower case to upper case.
print(z.swapcase())
# Out:
# pYTHON IS A iNTERPRETED lANGUAGE

# %%
x= "He's name is Dan. Dan is an honest man."#The title() method capitalizes each letter of the word within the string.
print(x.title())
# Out:
# He'S Name Is Dan. Dan Is An Honest Man.
