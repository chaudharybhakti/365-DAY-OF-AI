# %% [markdown]
# If we want to evaluate more than one condition, this can be done using an elif statement.

# %%
num = 0
if (num < 0):
    print("Number is negative.")
elif (num == 0):
    print("Number is Zero.")
else:
    print("Number is positive.")
# Out:
# Number is Zero.
