# %%
a="bhakti"
for b in a :
  print(b)
# Out:
# b
# h
# a
# k
# t
# i

# %%
for x in range (10):
  print("hloo")
# Out:
# hloo
# hloo
# hloo
# hloo
# hloo
# hloo
# hloo
# hloo
# hloo
# hloo

# %%
list=eval(input("enter a list"))#eval() converts the input into a Python list.
sum=0
for x in list:
  sum=sum+x
  print("sum=",sum)
# Out:
# sum= 1
# sum= 3
# sum= 6
# sum= 10
# sum= 15

# %%
x=1
while x<=1:
  print(x)
  x=x+1
# Out:
# 1
