# %%
import numpy as np

arr = np.array([10, 20, 30, 40])

print(np.mean(arr))
# Out:
# 25.0

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5, 6])

new_arr = arr.reshape(2, 3)

print(new_arr)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
import numpy as np

arr = np.array([10, 20, 30, 40])

print(arr[0])
print(arr[2])
# Out:
# 10
# 30

# %%
import numpy as np

arr = np.array([10, 20, 30, 40, 50])

print(arr[1:4])
# Out:
# [20 30 40]

# %%
import numpy as np

arr = np.array([[1, 2, 3],
                [4, 5, 6]])

print(arr)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
import numpy as np

arr = np.array([[1, 2, 3],
                [4, 5, 6]])

print(arr.shape)
# Out:
# (2, 3)
