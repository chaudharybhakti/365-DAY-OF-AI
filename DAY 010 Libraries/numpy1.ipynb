# %%
import numpy
arr=numpy.array([1,2,3,4,5])
print(arr)
# Out:
# [1 2 3 4 5]

# %%
import numpy as np

arr=np.array([1,2,3,4,5])
print(arr)
# Out:
# [1 2 3 4 5]

# %%
import numpy as np

arr=np.array([1,2,3,4,5])
print(arr[1:5:2])
# Out:
# [2 4]

# %%
import numpy as np

arr = np.zeros(5)

print(arr)
# Out:
# [0. 0. 0. 0. 0.]

# %%
import numpy as np

arr = np.ones(5)

print(arr)
# Out:
# [1. 1. 1. 1. 1.]

# %%
import numpy as np

arr = np.array([15, 40, 8, 25])

print("Maximum:", np.max(arr))
print("Minimum:", np.min(arr))
# Out:
# Maximum: 40
# Minimum: 8
