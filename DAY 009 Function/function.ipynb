# %%
def wish():
  print("Hello dear")

wish()
wish()
# Out:
# Hello dear
# Hello dear

# %%
import numpy
arr=numpy.array([1,2,3,4,5])
print(arr)
# Out:
# [1 2 3 4 5]

# %%
import numpy as np

arr=np.array([1,2,3,4,5])
print(arr)
# Out:
# [1 2 3 4 5]

# %%
import math
r=5
print("Area of circle =",(r))
# Out:
# Area of circle = 5
