# %%
student = {
    "name": "Rahul",
    "age": 20,
    "city": "Pune"
}

print(student)
# Out:
# {'name': 'Rahul', 'age': 20, 'city': 'Pune'}

# %%
d = {
    "a":1,
    "b":2,
    "c":3
}

print(d)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
d = {
    "a":1,
    "b":9,
    "c":3
}

print(d)
# Out:
# {'a': 1, 'b': 9, 'c': 3}

# %%
d = {
    "a":100,
    "b":100
}

print(d)
# Out:
# {'a': 100, 'b': 100}

# %%
d = {
    "name":"Bhakti",
    "age":18,
    "marks":85.5,
    "pass":True
}

print(d)
# Out:
# {'name': 'Bhakti', 'age': 18, 'marks': 85.5, 'pass': True}

# %%
student = {
    "name":"Rahul",
    "age":20
}
print(student.get("age"))
# Out:
# 20

# %%
student = {
    "age":20
}

student["age"] = 21

print(student)
# Out:
# {'age': 21}
